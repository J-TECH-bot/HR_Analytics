# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'people')
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %% [markdown]
# # EDA -  Exploratory data analysis(Data Preprocessing)
# -> Shape of the data
# -> Null value
# -> Duplicates
# -> Outliers
# -> Multicollienarity
# -> Vizualization

# %%
#shape of data
df.shape
# Out:
# (14999, 10)

# %%
# Information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
#Describe (It give statistical information about data)
df.describe()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       14999.000000    14999.000000      14999.000000     14999.000000
# mean            0.612834        0.716102          3.803054       201.050337
# std             0.248631        0.171169          1.232592        49.943099
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.440000        0.560000          3.000000       156.000000
# 50%             0.640000        0.720000          4.000000       200.000000
# 75%             0.820000        0.870000          5.000000       245.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       14999.000000  14999.000000  14999.000000           14999.000000
# mean            3.498233      0.144610      0.238083               0.021268
# ...

# %%
# Check null values
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
# deal with null values
#1 Drop the null value
#2 Replace it with mean, median or mode
# if we have large dataset we can drop the null value, but if the dataset is small we need to replace null values with the mean, median or mode

# %%
#Check dublicates in a dataset
#df.duplicated().sum()
#or 
df[df.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
# we can drop the duplicate data because they are already present in a dataset.
df = df.drop_duplicates()
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
#Check Outliners using box plot
plt.figure(figsize=(8, 6))
plt.boxplot(df['age'], vert=False)
plt.xlabel('Age')
plt.title('Box Plot for Age (Diabetes Dataset)')
plt.show()

# %%
# Correlation(Relationship between two columns)
correlation = df.corr()
correlation
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.006252          -0.152915      0.039940
# lastEvaluation                0.264678           0.096829     -0.005695
# numberOfProjects              0.331516           0.188837     -0.005612
# ...

# %%
# To show correlation we are using heat map
# for sowing values we are using annot
#for changing color we use cmap
sns.heatmap(correlation,annot = True,cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data vizualization

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
DV = ['dept', 'numberOfProjects', 'timeSpent.company', 'workAccident', 'promotionInLast5years', 'salary']
DV
# Out:
# ['dept',
#  'numberOfProjects',
#  'timeSpent.company',
#  'workAccident',
#  'promotionInLast5years',
#  'salary']

# %%
fig = plt.subplots(figsize=(20,25)) # Size of the figure
for i,j in enumerate(DV): # It is a built-in function in Python that allows you to loop over an iterable object and keep track of the index of each item
    print(i,j)
    plt.subplot(3,2,i+1) #(row,column,i=1(position))Devide the page
        
    sns.countplot(x=j, data=df, hue='left') # j is holding column names, df(data), hue(indicators)
        
    plt.xticks(rotation=90) # to rotate the values of x axis at 90 degree angle.
plt.show()
# Out:
# 0 dept
# 1 numberOfProjects
# 2 timeSpent.company
# 3 workAccident
# 4 promotionInLast5years
# 5 salary

# %%
# Now from graph We can conclude 
# We have to divide the projects equally because giving high number of projects to a single person increase work load and they decide to leave the company.
# Not low number of projects also because it give them less oppertunity to increase the work experience.
# Those who spent more time in a company will stay but those who are not able to acccomadate with the company policies they leave.
# Those who have high salary they are not leaving the company.
# Promote the experienced people. On the basis of some performence evaluation test.
